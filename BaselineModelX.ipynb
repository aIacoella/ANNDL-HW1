# %%
# Fix randomness and hide warnings
seed = 42
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# %%
# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)
print(tf.__version__)
# Out:
# 2.14.0

# %%
# Import other libraries
import cv2
from tensorflow.keras.applications.xception import preprocess_input
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
import seaborn as sns
from DataLoader import load_data

# %%
data_file = np.load("./public_data.npz", allow_pickle=True)
data = data_file["data"]
y = data_file["labels"]
y[y == "healthy"] = 0
y[y == "unhealthy"] = 1
y = y.astype(np.float32)

# %%
print("Removing trolls, shreks and duplicates")
initialDataN = data.shape[0]


troll = data[338]
shrek = data[58]


fig, axes = plt.subplots(1, 2, figsize=(6, 3))
axes[0].imshow(troll / 255)
axes[1].imshow(shrek / 255)
plt.tight_layout()
plt.show()
# Out:
# Removing trolls, shreks and duplicates

# %%
mask = []
for i in range(data.shape[0]):
    if np.array_equal(data[i], troll) or np.array_equal(data[i], shrek):
        mask.append(False)
    else:
        mask.append(True)
data = data[mask]
y = y[mask]

# %%
data, indexes = np.unique(data, axis=0, return_index=True)
y = y[indexes]

print("Removed Images: " + str(initialDataN - data.shape[0]))
# Out:
# Removed Images: 350

# %%
y = tfk.utils.to_categorical(y, num_classes=2)

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(
    data, y, random_state=seed, test_size=0.2, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, random_state=seed, test_size=0.2, stratify=y_train_val)

# %%
model = tfk.applications.Xception(
    input_shape=(96, 96, 3),
    include_top=False,
    weights="imagenet",
    pooling='avg',
)

# %%
model.trainable = False

inputs = tfk.Input(shape=(96, 96, 3))
x = model(inputs, training=False)

output = tfkl.Dense(2, activation="softmax")(x)
tl_model = tfk.Model(inputs, output)
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics=['accuracy'])
tl_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 96, 96, 3)]       0
#
#  xception (Functional)       (None, 2048)              20861480
#
#  dense (Dense)               (None, 2)                 4098
#
# =================================================================
# Total params: 20865578 (79.60 MB)
# Trainable params: 4098 (16.01 KB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
# Train the model
tl_history = tl_model.fit(
    x = preprocess_input(X_train), # We need to apply the preprocessing
    y = y_train,
    batch_size = 16,
    epochs = 20,
    validation_data = (preprocess_input(X_val), y_val),
    callbacks = [tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=20, restore_best_weights=True)]
).history
# Out:
# Epoch 1/20
# 194/194 [==============================] - 13s 53ms/step - loss: 0.5606 - accuracy: 0.7133 - val_loss: 0.4831 - val_accuracy: 0.7758
# Epoch 2/20
# 194/194 [==============================] - 9s 44ms/step - loss: 0.4881 - accuracy: 0.7680 - val_loss: 0.4735 - val_accuracy: 0.7732
# Epoch 3/20
# 194/194 [==============================] - 9s 46ms/step - loss: 0.4619 - accuracy: 0.7806 - val_loss: 0.4631 - val_accuracy: 0.7848
# Epoch 4/20
# 194/194 [==============================] - 9s 44ms/step - loss: 0.4397 - accuracy: 0.7916 - val_loss: 0.4899 - val_accuracy: 0.7732
# Epoch 5/20
# 194/194 [==============================] - 9s 44ms/step - loss: 0.4233 - accuracy: 0.8044 - val_loss: 0.4605 - val_accuracy: 0.7809
# Epoch 6/20
# 194/194 [==============================] - 9s 44ms/step - loss: 0.4203 - accuracy: 0.8112 - val_loss: 0.5040 - val_accuracy: 0.7680
# Epoch 7/20
# 194/194 [==============================] - 9s 44ms/step - loss: 0.3953 - accuracy: 0.8231 - val_loss: 0.4644 - val_accuracy: 0.7861
# Epoch 8/20
# 194/194 [==============================] - 9s 44ms/step - loss: 0.3862 - accuracy: 0.8289 - val_loss: 0.4725 - val_accuracy: 0.7874
# Epoch 9/20
# 194/194 [==============================] - 9s 49ms/step - loss: 0.3789 - accuracy: 0.8225 - val_loss: 0.4671 - val_accuracy: 0.7835
# Epoch 10/20
# 194/194 [==============================] - 9s 47ms/step - loss: 0.3707 - accuracy: 0.8341 - val_loss: 0.4793 - val_accuracy: 0.7899
# Epoch 11/20
# 194/194 [==============================] - 9s 45ms/step - loss: 0.3642 - accuracy: 0.8363 - val_loss: 0.4638 - val_accuracy: 0.7925
# Epoch 12/20
# 194/194 [==============================] - 8s 39ms/step - loss: 0.3546 - accuracy: 0.8466 - val_loss: 0.4777 - val_accuracy: 0.7784
# Epoch 13/20
# 194/194 [==============================] - 8s 40ms/step - loss: 0.3499 - accuracy: 0.8492 - val_loss: 0.4950 - val_accuracy: 0.7912
# Epoch 14/20
# 194/194 [==============================] - 8s 40ms/step - loss: 0.3433 - accuracy: 0.8495 - val_loss: 0.4645 - val_accuracy: 0.7938
# Epoch 15/20
# 194/194 [==============================] - 7s 36ms/step - loss: 0.3388 - accuracy: 0.8521 - val_loss: 0.4674 - val_accuracy: 0.7964
# Epoch 16/20
# 194/194 [==============================] - 7s 35ms/step - loss: 0.3393 - accuracy: 0.8553 - val_loss: 0.4948 - val_accuracy: 0.7822
# Epoch 17/20
# 194/194 [==============================] - 7s 35ms/step - loss: 0.3256 - accuracy: 0.8550 - val_loss: 0.4734 - val_accuracy: 0.7964
# Epoch 18/20
# 194/194 [==============================] - 7s 35ms/step - loss: 0.3224 - accuracy: 0.8669 - val_loss: 0.4793 - val_accuracy: 0.7835
# Epoch 19/20
# 194/194 [==============================] - 7s 36ms/step - loss: 0.3259 - accuracy: 0.8608 - val_loss: 0.4840 - val_accuracy: 0.7951
# Epoch 20/20
# 194/194 [==============================] - 7s 35ms/step - loss: 0.3107 - accuracy: 0.8702 - val_loss: 0.4962 - val_accuracy: 0.7951

# %%
# Plot the re-trained and the transfer learning MobileNetV2 training histories
plt.figure(figsize=(15,5))
plt.plot(tl_history['loss'], alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_loss'], label='Transfer Learning', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Categorical Crossentropy')
plt.grid(alpha=.3)

plt.figure(figsize=(15,5))
plt.plot(tl_history['accuracy'], alpha=.3, color='#4D61E2', linestyle='--')
plt.plot(tl_history['val_accuracy'], label='Transfer Learning', alpha=.8, color='#4D61E2')
plt.legend(loc='upper left')
plt.title('Accuracy')
plt.grid(alpha=.3)

plt.show()

# %%
# Save the best model
tl_model.save('XceptionTransferLearning')
del tl_model
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
